# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt, seaborn as sns

# %%
df1= pd.read_csv("/Users/Marcy_Student/Desktop/Projects /Shaping-Urban-Mobility-/data/hour.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   instant                  17379 non-null  int64
#  1   dteday                   17379 non-null  object
#  2   season                   17379 non-null  int64
#  3   mnth                     17379 non-null  int64
#  4   hr                       17379 non-null  int64
#  5   holiday                  17379 non-null  int64
#  6   weekday                  17379 non-null  int64
#  7   workingday               17379 non-null  int64
#  8   weathersit               17379 non-null  int64
#  9   temp                     17379 non-null  float64
#  10  atemp                    17379 non-null  float64
#  11  hum                      17379 non-null  float64
#  12  windspeed                17379 non-null  float64
#  13  casual                   17379 non-null  int64
#  14  registered               17379 non-null  int64
#  15  Total_amount_of_rentals  17379 non-null  int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 2.1+ MB

# %%
df1
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# 1               0           1  0.22  0.2727  0.80     0.0000       8
# 2               0           1  0.22  0.2727  0.80     0.0000       5
# 3               0           1  0.24  0.2879  0.75     0.0000       3
# 4               0           1  0.24  0.2879  0.75     0.0000       0
# ...           ...         ...   ...     ...   ...        ...     ...
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 0              13   16
# 1              32   40
# 2              27   32
# 3              10   13
# 4               1    1
# ...           ...  ...
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49
#
# [17379 rows x 17 columns]

# %%
# EDA and cleaning 
df = df1
# renaming columns that are a bit confusing 
df.rename(columns={'cnt':'Total_amount_of_rentals'},inplace=True)

# dropping columns that are not needed 
df= df.drop('yr',axis=1)
df= df.drop('workingday',axis=1)

# Creating a new column in df with the seasons_names
season_numbers= {1:'Winter',2:'Spring',3:'Summer',4:'Fall'}
df['season_names']= df['season'].map(season_numbers)

# Creating a new column with weekdays_name
weekday_numbers = {0:'Sunday',1:'Monday',2:'Tuesday',3:'Wednesday',4:'Thursday',5:'Friday',6:'Saturday'}
df['weekday_names'] = df ['weekday'].map(weekday_numbers)

#Creating column with the month_name
df['dteday'] = pd.to_datetime(df['dteday'])
df['month_names']=df['dteday'].dt.strftime('%B')

# seperateing it based on years 2011 and 2012 
df['year']=df['dteday'].dt.year

#convert the hour column to morning - afternoon - evening - night 
def part_of_day(hour):
    if 5 <= hour <12 : 
        return "Morning"
    elif 12 <= hour <17 :
        return "Afternoon"
    elif 17 <= hour <21 :
        return "Evening"
    else : return "Night"

df['time_of_day'] = df['hr'].apply(part_of_day)
df
# Out:
#        instant     dteday  season  mnth  hr  holiday  weekday  weathersit  \
# 0            1 2011-01-01       1     1   0        0        6           1
# 1            2 2011-01-01       1     1   1        0        6           1
# 2            3 2011-01-01       1     1   2        0        6           1
# 3            4 2011-01-01       1     1   3        0        6           1
# 4            5 2011-01-01       1     1   4        0        6           1
# ...        ...        ...     ...   ...  ..      ...      ...         ...
# 17374    17375 2012-12-31       1    12  19        0        1           2
# 17375    17376 2012-12-31       1    12  20        0        1           2
# 17376    17377 2012-12-31       1    12  21        0        1           1
# 17377    17378 2012-12-31       1    12  22        0        1           1
# 17378    17379 2012-12-31       1    12  23        0        1           1
#
#        temp   atemp   hum  windspeed  casual  registered  \
# 0      0.24  0.2879  0.81     0.0000       3          13
# 1      0.22  0.2727  0.80     0.0000       8          32
# 2      0.22  0.2727  0.80     0.0000       5          27
# 3      0.24  0.2879  0.75     0.0000       3          10
# 4      0.24  0.2879  0.75     0.0000       0           1
# ...     ...     ...   ...        ...     ...         ...
# 17374  0.26  0.2576  0.60     0.1642      11         108
# 17375  0.26  0.2576  0.60     0.1642       8          81
# 17376  0.26  0.2576  0.60     0.1642       7          83
# 17377  0.26  0.2727  0.56     0.1343      13          48
# 17378  0.26  0.2727  0.65     0.1343      12          37
#
#        Total_amount_of_rentals season_names weekday_names month_names  year  \
# 0                           16       Winter      Saturday     January  2011
# 1                           40       Winter      Saturday     January  2011
# 2                           32       Winter      Saturday     January  2011
# 3                           13       Winter      Saturday     January  2011
# 4                            1       Winter      Saturday     January  2011
# ...                        ...          ...           ...         ...   ...
# 17374                      119       Winter        Monday    December  2012
# 17375                       89       Winter        Monday    December  2012
# 17376                       90       Winter        Monday    December  2012
# 17377                       61       Winter        Monday    December  2012
# 17378                       49       Winter        Monday    December  2012
#
#       time_of_day
# 0           Night
# 1           Night
# 2           Night
# 3           Night
# 4           Night
# ...           ...
# 17374     Evening
# 17375     Evening
# 17376       Night
# 17377       Night
# 17378       Night
#
# [17379 rows x 20 columns]

# %%
# Observing customer behavior 

# Looking at the amount of rentals for time of day, throughout years ( 2011 and 2012 )
rentals_by_year = df.groupby(['time_of_day','year'])['Total_amount_of_rentals'].agg(['sum','std','min','max'])
print(rentals_by_year)

# Looking at rentals throughout the course of seasons 
rentals_by_season = df.groupby(['season_names','year'])['Total_amount_of_rentals'].agg(['sum','std','min','max'])
print(rentals_by_season)
# Out:
#                      sum         std  min  max
# time_of_day year
# Afternoon   2011  359231  110.947186    3  651
#             2012  596651  153.541335   10  783
# Evening     2011  393237  154.082472   11  638
#             2012  644734  226.654521   18  977
# Morning     2011  341950  118.378312    1  564
#             2012  579630  190.987351    1  839
# Night       2011  148685   59.146593    1  457
#             2012  228561   86.149665    1  584
#                       sum         std  min  max
# season_names year
# Fall         2011  326137  133.225077    1  625
#              2012  515476  212.462838    1  967
# Spring       2011  347316  138.421632    1  638
#              2012  571273  216.017955    1  957
# Summer       2011  419650  149.352219    1  651
#              2012  641479  226.013549    2  977
# Winter       2011  150000   67.447952    1  405
#              2012  321348  143.702976    1  801

# %%
# Looking at casual rentals throughout month within the years 2011 - 2012
casual_rentals_by_year = df.groupby(['year', 'month_names' ])['casual'].agg(['sum','min','max'])
print (casual_rentals_by_year)
# Out:
#                     sum  min  max
# year month_names
# 2011 April        22346    0  240
#      August       28842    0  196
#      December      8448    0  115
#      February      6242    0  108
#      January       3073    0   47
#      July         36452    0  248
#      June         30612    0  210
#      March        12826    0  175
#      May          31050    0  237
#      November     15594    0  191
#      October      25222    0  272
#      September    26545    0  245
# 2012 April        38456    0  355
#      August       43197    0  289
#      December     13245    0  167
#      February      8721    0  229
#      January       8969    0  156
#      July         41705    0  269
#      June         43294    0  297
#      March        31618    0  367
#      May          44235    0  361
#      November     21009    0  304
#      October      34538    0  362
#      September    43778    0  350

# %%
# Looking at casual rentals throughout the part of day within each month. 
casual_rentals_by_month = df.groupby(['time_of_day','year'])['casual'].agg(['sum','min','max'])
print( casual_rentals_by_month)
# Out:
#                      sum  min  max
# time_of_day year
# Afternoon   2011  101857    0  272
#             2012  164103    0  367
# Evening     2011   65024    0  240
#             2012   95575    0  347
# Morning     2011   51053    0  215
#             2012   76307    0  268
# Night       2011   29318    0  195
#             2012   36780    0  222

# %%
# Looking at the registered rentals information 
registered_rentals_by_day = df.groupby(['time_of_day','year'])['registered'].agg(['sum','min','max'])
print(registered_rentals_by_day)
# Out:
#                      sum  min  max
# time_of_day year
# Afternoon   2011  257374    3  502
#             2012  432548   10  526
# Evening     2011  328213    8  567
#             2012  549159   14  886
# Morning     2011  290897    0  514
#             2012  503323    1  808
# Night       2011  119367    0  262
#             2012  191781    0  362

# %%
registered_rentals_by_year = df.groupby(['year', 'month_names' ])['registered'].agg(['sum','min','max'])
print(registered_rentals_by_year)
# Out:
#                      sum  min  max
# year month_names
# 2011 April         72524    0  486
#      August       107849    0  549
#      December      78875    0  462
#      February      41973    0  275
#      January       35116    0  247
#      July         104889    1  517
#      June         112900    0  555
#      March         51219    0  312
#      May          104771    1  540
#      November      86573    1  523
#      October       98289    1  553
#      September    100873    0  567
# 2012 April        135768    1  697
#      August       171306    2  811
#      December     110468    1  737
#      February      94416    1  567
#      January       87775    1  518
#      July         161902    1  790
#      June         159536    3  796
#      March        133257    0  693
#      May          151630    1  770
#      November     131655    0  709
#      October      164303    1  876
#      September    174795    3  886

# %%
df.to_csv('modified_hours_dateset.csv',index = False)
